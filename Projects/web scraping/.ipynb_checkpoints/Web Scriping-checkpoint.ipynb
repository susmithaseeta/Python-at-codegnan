# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests # To read content from url
from bs4 import BeautifulSoup as bs # To make Content as HTML Format

# %%
search_element = "Nothing Phone 4b"
url = "https://www.flipkart.com/search?q=" + search_element.replace(" ","")
print(url)
# Out:
# https://www.flipkart.com/search?q=NothingPhone4b

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

web_response = requests.get(url, headers=headers)
web_response
# Out:
# <Response [200]>

# %%
web_response.text[:100]
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><'

# %%
web_content = bs(web_response.text, 'html.parser')
web_content
# Out:
# <!DOCTYPE html>
# ...

# %%
products = web_content.find_all('div', {'class':"lvJbLV col-12-12"})
print(len(products))
# Out:
# 10

# %%
product = products[2]
product_link = "https://www.flipkart.com" + product.div.div.div.a['href']
product_link
# Out:
# 'https://www.flipkart.com/nothing-phone-4b-white-128-gb/p/itm939608b40adbb?pid=MOBHZMBDSF3JAFTF&lid=LSTMOBHZMBDSF3JAFTF4PZFBR&marketplace=FLIPKART&q=NothingPhone4b&store=tyy%2F4io&spotlightTagId=default_BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=2a2b652d-209f-4e67-b972-691a6b46f34c.MOBHZMBDSF3JAFTF.SEARCH&ppt=None&ppn=None&ssid=vllj6r10sg0000001785220233498&qH=593b57c09431dbf2&ov_redirect=true'

# %%
product_name = product.div.div.div.a.find('div', {"class" : "RG5Slk"}).text
product_name
# Out:
# 'Nothing Phone (4b) (White, 128 GB)'

# %%
price = product.div.div.div.a.find('div', {"class" : "hZ3P6w DeU9vF"}).text
price
# Out:
# '₹34,999'

# %%
actual_price = product.div.div.div.a.find('div', {"class" : "kRYCnD gxR4EY"}).text
actual_price
# Out:
# '₹54,999'

# %%
discount = product.div.div.div.a.find('div', {"class" : "HQe8jr"}).text
discount
# Out:
# '36% off'

# %%
rating = product.div.div.div.a.find('div', {'class' : "MKiFS6"}).text
rating
# Out:
# '4.4'

# %%
product_desc_tags = product.div.div.div.a.find_all('li', {'class' : 'DTBslk'})
product_desc = []
for tag in product_desc_tags:
    product_desc.append(tag.text)
print(product_desc)
# Out:
# ['8 GB RAM | 128 GB ROM', '17.2 cm (6.77 inch) Full HD+ AMOLED Display', '50MP + 8MP | 16MP Front Camera', '6000 mAh Lithium ion Battery', '6 Gen 4 Processor', '1 Year Manufacturing Warranty']

# %%
import requests # To read content from url
from bs4 import BeautifulSoup as bs # To make Content as HTML Format

search_element = input("Enter product name")
url = "https://www.flipkart.com/search?q=" + search_element.replace(" ","")
# print(url)

try:
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9"
    }
    
    web_response = requests.get(url, headers=headers)
    # converting text into html paraser
    web_content = bs(web_response.text, 'html.parser')
    products = web_content.find_all('div', {'class':"lvJbLV col-12-12"})
    # iterate each product 
    for product in products:
        try:
            product_link = "https://www.flipkart.com" + product.div.div.div.a['href']
        except:
            product_link = "No Product Link"
        # Product Name 
        try:
            product_name = product.div.div.div.a.find('div', {"class" : "RG5Slk"}).text
        except:
            product_name = "No Product Name"
        # Rating 
        try:
            rating = product.div.div.div.a.find('div', {'class' : "MKiFS6"}).text
        except:
            rating = "No Rating"
        # Price
        try:
            price = product.div.div.div.a.find('div', {"class" : "hZ3P6w DeU9vF"}).text
        except:
            price = "No Price Found"
        # Actual_price
        try:
            actual_price = product.div.div.div.a.find('div', {"class" : "kRYCnD gxR4EY"}).text
        except:
            actual_price = "No Actual Price"
        # Discount
        try:
            discount = product.div.div.div.a.find('div', {"class" : "HQe8jr"}).text
        except:
            discount = "No Discount"
        # description
        try:
            product_desc_tags = product.div.div.div.a.find_all('li', {'class' : 'DTBslk'})
            product_desc = []
            for tag in product_desc_tags:
                product_desc.append(tag.text)
        except:
            product_desc = "No Product Description"
        # Product Info
        product_info = {
            'Product Name' : product_name,
            'Price' : price,
            'Actual Price' : actual_price,
            'Discount' : discount,
            'Description' : product_desc,
            'Rating' : rating,
            'Product Link' : product_link
        }
        print(product_info)
        print("*" * 100)
except:
    print("Site not allow you to scrap")
# Out:
# Enter product name Nothing Phone 4b
# {'Product Name': 'No Product Name', 'Price': 'No Price Found', 'Actual Price': 'No Actual Price', 'Discount': 'No Discount', 'Description': 'No Product Description', 'Rating': 'No Rating', 'Product Link': 'No Product Link'}
# ****************************************************************************************************
# {'Product Name': 'No Product Name', 'Price': 'No Price Found', 'Actual Price': 'No Actual Price', 'Discount': 'No Discount', 'Description': 'No Product Description', 'Rating': 'No Rating', 'Product Link': 'No Product Link'}
# ****************************************************************************************************
# ...

# %%
import requests # To read content from url
from bs4 import BeautifulSoup as bs # To make Content as HTML Format
import pandas as pd

search_element = input("Enter product name")
url = "https://www.flipkart.com/search?q=" + search_element.replace(" ","")
# creating dataframe
df = pd.DataFrame(columns = ['Product Name',
                            'Price',
                            'Actual Price',
                            'Discount',
                            'Description',
                            'Rating',
                            'Product Link'
                            ])

try:
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9"
    }
    
    web_response = requests.get(url, headers=headers)
    # converting text into html paraser
    web_content = bs(web_response.text, 'html.parser')
    products = web_content.find_all('div', {'class':"lvJbLV col-12-12"})
    # iterate each product 
    for product in products:
        try:
            product_link = "https://www.flipkart.com" + product.div.div.div.a['href']
        except:
            product_link = "No Product Link"
        # Product Name 
        try:
            product_name = product.div.div.div.a.find('div', {"class" : "RG5Slk"}).text
        except:
            product_name = "No Product Name"
        # Rating 
        try:
            rating = product.div.div.div.a.find('div', {'class' : "MKiFS6"}).text
        except:
            rating = "No Rating"
        # Price
        try:
            price = product.div.div.div.a.find('div', {"class" : "hZ3P6w DeU9vF"}).text
        except:
            price = "No Price Found"
        # Actual_price
        try:
            actual_price = product.div.div.div.a.find('div', {"class" : "kRYCnD gxR4EY"}).text
        except:
            actual_price = "No Actual Price"
        # Discount
        try:
            discount = product.div.div.div.a.find('div', {"class" : "HQe8jr"}).text
        except:
            discount = "No Discount"
        # description
        try:
            product_desc_tags = product.div.div.div.a.find_all('li', {'class' : 'DTBslk'})
            product_desc = []
            for tag in product_desc_tags:
                product_desc.append(tag.text)
        except:
            product_desc = "No Product Description"
        # Product Info
        product_info = {
            'Product Name' : product_name,
            'Price' : price,
            'Actual Price' : actual_price,
            'Discount' : discount,
            'Description' : product_desc,
            'Rating' : rating,
            'Product Link' : product_link
        }
        df.loc[len(df)] = product_info

        # print(product_info)
        # print("*" * 100)
    df.to_csv(f'{search_element.replace(" ","")}.csv')
    print(f'{search_element} data saved as CSV file')
except:
    print("Site not allow you to scrap")
# Out:
# Enter product name one plus nord ce3
# one plus nord ce3 data saved as CSV file
