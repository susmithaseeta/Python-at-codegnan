# %%
units = int(input("Enter units: "))
is_senior = input("Is senior citizen? yes/no: ").lower()

if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = units * 2.5
elif units <= 500:
    bill = units * 4
else:
    bill = units * 6
    
if is_senior == "yes":
    bill = bill - (bill * 0.10)

if units > 800:
    bill = bill + (bill * 0.05)

print("Final Bill Amount: Rs", round(bill, 2))
# Out:
# Enter units:  450
# Is senior citizen? yes/no:  yes
# Final Bill Amount: Rs 1620.0

# %%
# 2. Key word arguments: Arguments are explicity passed with parameter names
# function defination block
def sub(x:int,y:int)->int:
    z = x - y
    return z
# function calling block
a, b = 20, 10
print(sub(x = a,y = b))
print(sub(y = b,x = a))
# Out:
# 10
# 10

# %%
# 2. Key word arguments: Arguments are explicity passed with parameter names
# function defination block
def add(x:int,y:int)->int:
    z = x + y
    return z
# function calling block
a, b = 20, 10
print(add(x = a,y = b))
print(add(y = b,x = a))
print(add(5, y = 10))
# Out:
# 30
# 30
# 15

# %%
# 3 - variable addition
# function defination block
def add(x:int,y:int,z:int)->int:
    p = x + y + z
    return p
# function calling block
a, b ,c= map(int,input().split())
print(add(a,b,c))
# Out:
#  1 2 3
# 6

# %%
# 4 - variable addition
# function defination block
def add(w:int,x:int,y:int,z:int)->int:
    p = w + x + y + z
    return p
# function calling block
a, b ,c, d= map(int,input().split())
print(add(a,b,c,d))
# Out:
#  1 2 3 4
# 10

# %%
# function defination block
def add(w:int,x:int,y:int = 0,z:int = 0)->int:
    p = w + x + y + z
    return p
# function calling block
a, b ,c, d= map(int,input().split())
print(add(a,b))
print(add(a,b,c))
print(add(a,b,c,d))
# Out:
#  1 2 3 4
# 3
# 6
# 10

# %%
# function defination block
def mul(w:int,x:int,y:int = 1,z:int = 1)->int:
    p = w * x * y * z
    return p
# function calling block
a, b ,c, d= map(int,input().split())
print(mul(a,b))
print(mul(a,b,c))
print(mul(a,b,c,d))
# Out:
#  1 2 3 4
# 2
# 6
# 24

# %%
# Variable Length Positional arguments
def add(x,y = 0, *args):

    print(type(args))
    print(args)
    s = 0
    for val in args:
        s+= val
    return s
print(add(10,20,1,2,3,4,5))
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# 15

# %%
#using global scope variable in local scope
x = 100
def outer():
    y = x + 1
    print("Local Scope variable value:",y)
outer()
print("Global scope value:",x)
# Out:
# Local Scope variable value: 101
# Global scope value: 100

# %%
# Updating the  global scope variable value in local scope
# Can't update global scope variable in local scope directly 
x = 100
def outer():
    x = x + 1
    print("Local Scope variable value:",x)
outer()
print("Global scope value:",x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 6
#       2 x = 100
#       3 def outer():
#       4     x = x + 1
#       5     print("Local Scope variable value:",x)
# ----> 6 outer()
#       7 print("Global scope value:",x)
#
# Cell In[10], line 4, in outer()
#       3 def outer():
# ----> 4     x = x + 1
#       5     print("Local Scope variable value:",x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
# Updating the  global scope variable value in local scope by using ' global ' keyword
x = 100
def outer():
    global x
    x = x + 1
    print("Local Scope variable value:",x)
outer()
print("Global scope value:",x)
# Out:
# Local Scope variable value: 101
# Global scope value: 101

# %%
# Updating the Enclosing Scope variable in local scopeby using non-local
x = 100 # global scope variable
def outer():
    x = 200
    x = x + 2
    print("Local scope variable x value:",x)
outer()
print("Global scope variable x value:",x)
# Out:
# Local scope variable x value: 202
# Global scope variable x value: 100

# %%
s1 = "CODE"
s2 = "GNAN"
print(abs(ord(s2)-ord(s1)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 s1 = "CODE"
#       2 s2 = "GNAN"
# ----> 3 print(abs(ord(s2)-ord(s1)))
#
# TypeError: ord() expected a character, but string of length 4 found

# %%
s1 = "CODE"
s2 = "GNAN"
n = len(s1)
r1 = ""
r2 = ""
for i in range(n):
    if abs(ord(s1[i]) > ord(s2[i])):
        r1 += s1[i].upper()
    else:
        r2 += s2[i].lower()
print(r1)
print(r2)
# Out:
# OD
# gn

# %%
# find bigger and smaller character from s1 and s2
# compare each character in both strins and if s1[i] > s2[i] to bigger and s2[i] to smaller 
# if both same leave it
s1, s2 = map(str,input().upper().split())
n = len(s1)
big = small = ""
for i in range(n):
    if s1[i] != s2[i]:
        if s1[i] > s2[i]:
            big += s1[i]
            small +=s2[i]
        else:
            big +=s2[i]
            small +=s1[i]
print(big)
print(small)
# Out:
#  code GNAN
# GODN
# CNAE

# %%
# filter the even numbers from list of integers 
def even(x):
    if x % 2 == 0:
        return 1
    return -1
arr = [1,2,3,4,5,6,7]
print(filter(even,arr))
print(list(filter(even,arr)))
print(list(map(even,arr)))
# Out:
# ...
# [1, 2, 3, 4, 5, 6, 7]
# [-1, 1, -1, 1, -1, 1, -1]

# %%
def squere(t):
    x, y = t
    return x + y
lst = [(1,2),(3,4)]
print(list(map(squere,lst)))
# Out:
# [3, 7]

# %%
# zip(iterable1,iterable2,....., iterableN)
# It returns list of tuple 
l1 = ['a','b','c']
l2 = [1,2,3,4,5]
print(list(zip(l1,l2)))
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
# User table
users = {
    1234:{"name" : "Susmitha", "Email" : "susmithaseeta@gmail.com", "balance" : 5000, "password" : "1234"},
    1235:{"name" : "Seeta", "Email" : "susmithaseeta@codegnan.com", "balance" : 5000, "password" : "1235"}
    }

# Services
def register(name : str, Email : str, initial_deposite : int, password : str):
    pass

# Login
def login(account : int, password : str) -> bool:
    pass

# Balance function defination
def balance(account : int) -> int:
    pass

# withdraw function defination
def withdraw(account : int, withdraw_amount : int) ->str:
    pass

# Deposite function defination
def deposit(account : int, deposit_amount : int):
    pass

# Transfer function defination
def transfer(sender : int, reciever : int, transfer_amount : int):
    pass 

# Ministatement Function Defination
def ministatement(account : int):
    pass

# logout Function Defination
def logout():
    pass

# main
if __name__ == "__main__":
    
    print("Welcome to the small scale bank")
    print("1. Register \n 2. Login")
    choice = int(input("Select Your choice:"))

    # calling register function
    if choice == 1:
        print("Registation Page Under Development Process....")

    # calling Login Function
    elif choice == 2:
        account = int(input("Enter Your Account Number:"))
        password = input("Enter Your Password:")
        login_val = login(account = account, password = password)

        while login_val:
            print("The small scale Bank Providing services")
            print("1. Balance \n 2. Withdraw \n 3. Deposite \n \
                   4. Transfer \n 5. Ministatement \n 6. Logout")
            choice = int(input("Enter your choice(1-6):"))

            if choice == 1:
                # call Balance Function
                current_balance = balance(account = account)

            elif choice == 2:
                amount = int (input("Enter your withdraw amount:"))
                # call withdraw function
                res = withdraw(account = account, withdraw_amount = amount)
                print(res)
            elif choice == 3:
                amount = int (input("Enter your deposit amount:"))
                # call deposit function
                res = deposit(account = account, deposit_amount = amount)
                print(res)
            elif choice == 4:
                receiver = int(input("Enter Receiver Account Number: "))
                amount = int(input("Enter Transfer Amount: "))
                print(transfer(account, receiver, amount))
            elif choice == 5:
                res = ministatement(account = account)
                print(res)
            elif choice == 6:
                login_val = logout()
            else:
                print("Invalid Choice")
else:
    print("Invaild Option")
# Out:
# Welcome to the small scale bank
# 1. Register
#  2. Login
# Select Your choice: 2
# Enter Your Account Number: 1234
# Enter Your Password: 1234

# %%
# who will return the top (100) in less steps
import random
rolls = 0
count = 0
while count <= 100:
    random.randint(1,6)
    rolls += 1
    
print(rolls)

# %%
# class attribute - school
# instance attribute - id,name,class
class Student:
    school = "Codegnan school"
    def __init__(self, stdid, name,standard):
        self.name = name 
        self.stdid = stdid
        self.standard = standard
    def student_details(self):
        return f"My name is {self.name} and I am from {self.standard} class"
s = Student(429,"Susmitha", 16)
print(s.name)
print(s.school)
print(s.student_details())
# Out:
# Susmitha
# Codegnan school
# My name is Susmitha and I am from 16 class

# %%
# Instance Method:
# class attribute - school
# instance attribute - id,name,class
class Student:
    school = "Codegnan school" # class attribute
    def __init__(self, stdid, name,standard):
        self.name = name # instance attribute
        self.stdid = stdid # instance attribute
        self.standard = standard # instance attribute
    def student_details(self): # instance Method
        return f"My name is {self.name} and I am from {self.standard} class"
    # class method
    @classmethod
    def update_school(cls, new_school_name):
        cls.school = new_school_name
        return "School name Updated"
    @staticmethod
    def percentage(marks : list):
        return (sum(marks)/300) * 100
        
s1 = Student(429,"Susmitha", 9)
s2 = Student(430,"Akshya", 10)
print(s1.school, s2.school)
print(s.student_details())
print(s1.update_school("CODEGNAN school"))
print(s1.school, s2.school)
print(s2.percentage([75,85,95]))
# Out:
# Codegnan school Codegnan school
# My name is Susmitha and I am from 16 class
# School name Updated
# CODEGNAN school CODEGNAN school
# 85.0

# %%
# Instance Method:
# class attribute - school
# instance attribute - id,name,class
class Student:
    school = "Codegnan school" # class attribute
    def __init__(self, stdid, name,standard):
        self.name = name # instance attribute
        self.stdid = stdid # instance attribute
        self.standard = standard # instance attribute
    def student_details(self): # instance Method
        return f"My name is {self.name} and I am from {self.standard} class"
    # class method
    @classmethod
    def update_school(cls, new_school_name):
        cls.school = new_school_name
        return "School name Updated"
    @staticmethod
    def percentage(marks : list):
        return (sum(marks)/300) * 100
        
# s1 = Student(429,"Susmitha", 9)
# s2 = Student(430,"Akshya", 10)
# print(s1.school, s2.school)
# print(s.student_details())
print(Student.school)
print(Student.update_school("CODEGNAN school"))
print(Student.school)
print(Student.percentage([75,85,95]))
# Out:
# Codegnan school
# School name Updated
# CODEGNAN school
# 85.0

# %%
class Bank:
    def __init__(self, name, account,  password, balance):
        self.name = name
        self.account = account
        self.__password = password
        self._balance = balance
    def __total_users(self): # getter method
        return "Total users : 101"
    def get_balance(self): # getter method
        return f"Current Balance is:{self._balance}"
    def deposite(self, deposite_amount): # setter method
        self._balance += deposite_amount
        return f"{deposite_amount} Deposited Successfully"
        
u1 = Bank("Susmitha", 1001, "Susmitha@123", 10000)
print(u1.name)
print(u1.get_balance())
print(u1.deposite(5000))
print(u1.get_balance())
# Out:
# Susmitha
# Current Balance is:10000
# 5000 Deposited Successfully
# Current Balance is:15000

# %%
class Bank:
    def __init__(self, name, account,  password, balance):
        self.name = name
        self.account = account
        self.__password = password
        self._balance = balance
    def __total_users(self): # getter method
        return "Total users : 101"
    def get_balance(self): # getter method
        return f"Current Balance is:{self._balance}"
    def deposite(self, deposite_amount): # setter method
        self._balance += deposite_amount
        return f"{deposite_amount} Deposited Successfully"
        
u1 = Bank("Susmitha", 1001, "Susmitha@123", 10000)
print(u1.name)
print(u1.get_balance())
print(u1.deposite(5000))
print(u1.get_balance())
print(u1._balance) # Protected member access in outside the class
print(u1._Bank__total_users()) # Name Mangling : Syntax: obj._classname__attribute
# Out:
# Susmitha
# Current Balance is:10000
# 5000 Deposited Successfully
# Current Balance is:15000
# 15000
# Total users : 101

# %%
class A:
    def show()
class B:
    def show()
b = B()
b.show()
# Out:
#   Cell In[2], line 2
#     def show()
#               ^
# SyntaxError: expected ':'

# %%
from abc import ABC, abstractmethod
class Mobile(ABC):
    @abstractmethod
    def ram(self):
        pass
    @abstractmethod
    def rom(self):
        pass
    @abstractmethod
    def battery(self):
        pass
    # concreate method implementation
    def display(self, Hzs):
        return f"This mobile display quality is {Hzs} Hzs"
class Oppo(Mobile):
    def __init__(self, model, battery_size, display_quality):
        self.model = model
        self.battery_size = battery_size
        self.display_quality = display_quality
    def ram(self, ram_size):
        return f"This Oppo mobile {self.model} has {ram_size} GB RAM"
    def rom(self, rom_size):
        return f"This Oppo mobile {self.model} has {rom_size} GB ROM"
    def battery(self):
        return f"This Oppo mobile {self.model} has {self.battery} mah Battery Capacity"
    def camera(self, primary, secondary):
        return f"The Oppo {self.model} mobile have primary camera with {primary} MP and seconday camera with {secondary} MP"
# m = Mobile()  TypeError: Can't instantiate abstract class Mobile without an implementation for abstract methods 'battery', 'ram', 'rom'
reno15 = Oppo("reno15", 5000, 120)
print(reno15.ram(4))
print(reno15.rom(128))
print(reno15.battery())
print(reno15.camera(32, 52))
print(reno15.display(120))
# Out:
# This Oppo mobile reno15 has 4 GB RAM
# This Oppo mobile reno15 has 128 GB ROM
# This Oppo mobile reno15 has <bound method Oppo.battery of <__main__.Oppo object at 0x00000265AC469A90>> mah Battery Capacity
# The Oppo reno15 mobile have primary camera with 32 MP and seconday camera with 52 MP
# This mobile display quality is 120 Hzs

# %% [markdown]
# #### ty

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
s = Student("seeta",21)
print(s.gender)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       2     def __init__(self,name,age):
#       3         self.name = name
#       4         self.age = age
#       5 s = Student("seeta",21)
# ----> 6 print(s.gender)
#       7
#       8
#
# AttributeError: 'Student' object has no attribute 'gender'

# %%
# try block with exception 
try:
    list = [1,2,3]
    print(list[10])
    print("hi")
except:
    print("something wrong in try block")
else:
    print("No Exception raised in try block")
finally:
    print("Program done")
# Out:
# something wrong in try block
# Program done

# %%
# try block without exception
try:
    list = [1,2,3]
    print(list[2])
    print("hi")
except:
    print("something wrong in try block")
else:
    print("No Exception raised in try block")
finally:
    print("Program done")
# Out:
# 3
# hi
# No Exception raised in try block
# Program done

# %%
# we can't handle the syntax error 
try:
    print("Hello')
except:
    print("something wrong in try block")
else:
    print("No Exception raised in try block")
finally:
    print("Program done")
# Out:
#   Cell In[8], line 3
#     print("Hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
try:
    a = 10
    b = 0
    c = a / b
    print(c) 
except Exception as e:
    print(f"Something wrong in try block: {e}")
# Out:
# Something wrong in try block: division by zero

# %%
a = 10
    b = a.append(0)
    print(b)
# Out:
#   Cell In[10], line 3
#     b = a.append(0)
#     ^
# IndentationError: unexpected indent

# %%
try:
    a = 10
    b = a.append(0)
    print(b) 
except Exception as e:
    print(f"Something wrong in try block: {e}")
# Out:
# Something wrong in try block: 'int' object has no attribute 'append'

# %%
try:
    a = 10
    b = a.append(0)
    print(b) 
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value error raised in try block: {e}")
# except Exception as e:
#   print(f"Something wrong in try block: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       4     b = a.append(0)
#       5     print(b)
#       6 except ZeroDivisionError as e:
#       7     print(f"Zero division not possible: {e}")
# ----> 8 except ValueError as e:
#       9     print(f"Value error raised in try block: {e}")
#      10 # except Exception as e:
#      11 #   print(f"Something wrong in try block: {e}")
#
# AttributeError: 'int' object has no attribute 'append'

# %%
try:
    a = 10
    b = 0
    c = a / b
    print(c) 
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value error raised in try block: {e}")
# except Exception as e:
#   print(f"Something wrong in try block: {e}")
# Out:
# Zero division not possible: division by zero

# %%
# It execute the specific exception block when specified exception raised otherwise,
#             it executes the common except block
try:
    a = 10
    b = a.append(1)
    c = a / b
    print(c) 
except ZeroDivisionError as e:
    print(f"Zero division not possible: {e}")
except ValueError as e:
    print(f"Value error raised in try block: {e}")
except Exception as e: # common exception block with Exception class
   print(f"Something wrong in addition.add: {e}")
# Out:
# Something wrong in addition.add: 'int' object has no attribute 'append'
