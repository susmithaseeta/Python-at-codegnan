# %%
a,b = map(int,input().split())
floor_val = a // b
ceil_val = (a+b-1) // b
round_val = (a+b // 2) // b
print(f"floor {a} / {b} = {floor_val}") 
print(f"ceil {a} / {b} = {ceil_val}") 
print(f"round {a} / {b} = {round_val}")
# Out:
#  10 3
# floor 10 / 3 = 3
# ceil 10 / 3 = 4
# round 10 / 3 = 3

# %%
'''
a,b,c = map(int,input().split())
# minimum
if a<=b and a<=c:
    mn=a
elif b<=a and b<=c:
    mn=b
else:
    print(c)
# maximum
if a>=b and a>=c:
    print(a)
elif b>=a and b>=c:
    print(b)
else:
    print(c)
    '''

a,b,c = map(int,input().split())

print(min(a,b,c), max(a,b,c))
# Out:
#  1 2 3
# 1 3

# %%
num = input().split()
int_val = int(num[0])
long_long_val = int(num[1])
char_val = num[2]
float_val = float(num[3])
double_val = float(num[4])

print(int_val)
print(long_long_val)
print(char_val)
print(float_val)
print(double_val)
# Out:
#  3 12345678912345 a 334.23 14049.30493
# 3
# 12345678912345
# a
# 334.23
# 14049.30493

# %%
x,y = map(int,input().split())
print(f"{x} + {y} = {x+y}")
print(f"{x} * {y} = {x*y}")
print(f"{x} - {y} = {x-y}")
# Out:
#  5 10
# 5 + 10 = 15
# 5 * 10 = 50
# 5 - 10 = -5

# %%
n,m = map(int,input().split())
last_digit_n = n% 10
last_digit_m = m% 10
print(last_digit_n + last_digit_m)
# Out:
#  13 12
# 5

# %%
n = int(input())
r = n*(n+1)//2
print(r)
# Out:
#  10
# 55

# %%
a,b = map(int,input().split())
if a>=b:
    print("Yes")
else:
    print("No")
# Out:
#  10 9
# Yes

# %%
a,b = map(int,input().split())
if a % b == 0 or  b % a == 0:
        print("Multiples")
else:
        print("No Multiples")
# Out:
#  9 3
# Multiples

# %%
n = input()
int_val, float_val = n.split('.')
if int(float_val) == 0:
    print(f"int {int_val}")
else:
    print(f"float {int_val} 0.{float_val}")
# Out:
#  234.000
# int 234

# %%
x = input()
if x.isdigit():
    print("IS DIGIT")
else:
    print("ALPHA")
    if x.isupper():
        print("IS CAPITAL")
    else:
        print("IS SMALL")
# Out:
#  A
# ALPHA
# IS CAPITAL

# %%
x = input()
print(x.swapcase())
# Out:
#  a
# A

# %%
s = input()
s = s.replace('/' , '//')
print(eval(s))
# Out:
#  7+54
# 61

# %%
x = input()
first_digit = int(x[0])

if first_digit % 2 == 0:
    print("EVEN")
else:
    print("ODD")
# Out:
#  4569
# EVEN

# %%
x, y = map(float, input().split())

if x == 0 and y == 0:
    print("Origem")
elif x == 0:
    print("Eixo Y")
elif y == 0:
    print("Eixo X")
elif x > 0 and y > 0:
    print("Q1")
elif x < 0 and y > 0:
    print("Q2")
elif x < 0 and y < 0:
    print("Q3")
else:  # x > 0 and y < 0
    print("Q4")
# Out:
#  4.5 -2.2
# Q4

# %%
num = int(input())
years = num // 365
num = num % 365
months = num // 30
days = num % 30

print(f"{years} years")
print(f"{months} months")
print(f"{days} days")
# Out:
#  400
# 1 years
# 1 months
# 5 days

# %%
arr = list(map(int,input().split()))
ori = arr[:]
arr.sort()

for x in arr:
    print(x)
print()
for x in ori:
    print(x)
# Out:
#  3 -2 1
# -2
# 1
# 3
#
# 3
# -2
# 1

# %%
a,s,b,q,c = input().split()
a = int(a)
b = int(b)
c = int(c)
if s == '+':
    ans = a + b
elif s == '-':
    ans = a - b
else:
    ans = a * b
if ans == c:
    print("Yes")
else:
    print(ans)
# Out:
#  5+10=15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a,s,b,q,c = input().split()
#       2 a = int(a)
#       3 b = int(b)
#       4 c = int(c)
#
# ValueError: not enough values to unpack (expected 5, got 1)

# %%
s = input()
left,c = s.split('=')
a,b = left.split('+')
ans = int(a) + int(b)
print("Yes" if ans == int(c) else ans)
# Out:
#  5+10=15
# Yes

# %%
s = input()
left, c = s.split('=')
c = int(c)
ans = eval(left)
print("Yes" if ans == c else ans)
# Out:
#  5+10=15
# Yes

# %%
f1, s1 = input().split()
f2, s2 = input().split()
if s1 == s2:
    print("ARE Brothers")
else:
    print("NOT")
# Out:
#  bassam ramadan
#  ahmed ramadan
# ARE Brothers

# %%
a,s,b = input().split()
a = int(a)
b = int(b)

if s == '<':
    ans = a < b
elif s == '>':
    ans = a > b
else:
    ans = a == b
print("Right" if ans else "Wrong")
# Out:
#  9<1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 a,s,b = input().split()
#       2 a = int(a)
#       3 b = int(b)
#       4
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
s = input().split()
if '<' in s:
    a,b = s.split('<')
    a = int(a)
    b = int(b)
    if a < b:
        print("Right")
    else:
        print("Wromg")
elif '>' in s:
    a,b = s.split('>')
    a = int(a)
    b = int(b)
    if a > b:
        print("Right")
    else:
        print("Wrong")
else:
    a,b = s.split('=')
    a = int(a)
    b = int(b)
    if a == b:
        print("Right")
    else:
        print("Wrong")
# Out:
#  9<1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 19
#      15         print("Right")
#      16     else:
#      17         print("Wrong")
#      18 else:
# ---> 19     a,b = s.split('=')
#      20     a = int(a)
#      21     b = int(b)
#      22     if a == b:
#
# AttributeError: 'list' object has no attribute 'split'

# %%
A, S, B = input().split()

A = int(A)
B = int(B)

if S == "<":
    print("Right" if A < B else "Wrong")
elif S == ">":
    print("Right" if A > B else "Wrong")
else: 
    print("Right" if A == B else "Wrong")
# Out:
#  5 > 4
# Right

# %%
A, S, B = input().split()

# Check if we got exactly three parts
if len([A, S, B]) != 3:
    print("Wrong input format")
else:
    A = int(A)
    B = int(B)

    if S == "<":
        print("Right" if A < B else "Wrong")
    elif S == ">":
        print("Right" if A > B else "Wrong")
    elif S == "=":
        print("Right" if A == B else "Wrong")
    else:
        print("Invalid comparison symbol")
# Out:
#  5 > 4
# Right

# %%
l1,r1,l2,r2 = map(int,input().split())
left = max(l1,l2)
right = min(r1,r2)
 
if left <= right:
    print(left,right)
else:
    print(-1)
# Out:
#   Cell In[53], line 4
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
s = input().split()

if len(s)!= 4:
    print("Enter 4 numbers: l1 r1 l2 r2")
else:
    l1, r1, l2, r2 = int(s[0]), int(s[1]), int(s[2]), int(s[3])

    left = max(l1, l2)
    right = min(r1, r2)

    if left <= right:
        print(left, right)
    else:
        print(-1)
# Out:
#  1 15 5 27
# 5 15

# %%
s = input().split()
l1, r1, l2, r2 = int(s[0]), int(s[1]), int(s[2]), int(s[3])

left = l1 if l1 > l2 else l2
right = r1 if r1 < r2 else r2

if left <= right:
    print(left, right)
else:
    print(-1)
# Out:
#  1 15 5 27
# 5 15

# %%
x = float(input())

if 0 <= x <= 25:
    print("Interval [0,25]")
elif 25 < x <= 50:
    print("Interval (25,50]")
elif 50 < x <= 75:
    print("Interval (50,75]")
elif 75 < x <= 100:
    print("Interval (75,100]")
else:
    print("Out of Intervals")
# Out:
#  25.1
# Interval (25,50]

# %%
a, b, c, d = map(int, input().split())

result = (a % 100) * (b % 100) % 100
result = (result * (c % 100)) % 100
result = (result * (d % 100)) % 100

print(result)
# Out:
#  3 9 9 9
# 87

# %%
a, b, c, d = map(int, input().split())
print((a * b * c * d) % 100)
# Out:
#  3 9 9 9
# 87

# %%
a,b,c,d = map(int,input().split())
r = a*b*c*d
last_two_digit = r % 100
print(last_two_digit)
# Out:
#  3 9 9 9
# 87

# %%
a,b,c,d = map(int,input().split())
if a == 1 and c == 1:
    print("NO")
elif a == 1:
    print("NO")
elif c == 1:
    print("YES")
else:
    print("NO")
# Out:
#  5 2 4 2
# NO

# %%
import math
A, B, C, D = map(int, input().split())

if B * math.log(A) > D * math.log(C):
    print("YES")
else:
    print("NO")
# Out:
#  5 2 5 2
# NO

# %%
string = "programmer"
print(f"Hello, {string}")
# Out:
# Hello, programmer
